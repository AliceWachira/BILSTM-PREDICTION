# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Loading the data
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os, glob


path = "/content/gdrive/MyDrive/AIMS ESSAY/DATASET 1/LINK_CSV"
all_files = glob.glob(os.path.join(path, "*.csv"))
linkId_files=[]

for filename in all_files:
  df = pd.read_csv(filename,sep=',')
  linkId_files.append(df)

# %%
linkId_files[3]
# Out:
#        Speed  TravelTime   linkId       Id        Date      Time
# 0      62.76          79  4616214  3946625  2016-01-01  00:01:01
# 1      60.89          82  4616214  3946805  2016-01-01  00:06:01
# 2      60.27          84  4616214  3946927  2016-01-01  00:11:01
# 3      62.14          81  4616214  3947058  2016-01-01  00:16:01
# 4      57.17          88  4616214  3947183  2016-01-01  00:21:01
# ...      ...         ...      ...      ...         ...       ...
# 93365   4.97         863  4616214  2813452  2016-12-31  23:36:06
# 93366   3.11        1450  4616214  2813567  2016-12-31  23:41:06
# 93367   1.86        2121  4616214  2813687  2016-12-31  23:46:06
# 93368   1.86        2188  4616214  2813739  2016-12-31  23:49:06
# 93369   1.86        2342  4616214  2813917  2016-12-31  23:56:06
#
# [93370 rows x 6 columns]

# %%
df=linkId_files[3]

# %%
#This function adds the column of the weekday to the dataset 
def linkcsv(file,month,week,day):
  #file is the name of te csv file you desire
  file['Date']=pd.to_datetime(file.Date, format='%Y-%m-%d')
  #Adding the month column from date column
  file['Month'] = pd.DatetimeIndex(file['Date']).month
  file['Day'] = pd.DatetimeIndex(file['Date']).day
  file['Weekday'] = file['Date'].dt.day_name()
  file['week'] = file['Date'].dt.week

  #This will extract the month you want
  file_month=file.loc[file['Month']==month]
  file_week=file_month.loc[file['week']==week]
  file_day=file_week.loc[file['Weekday']==day]
  return file_day

# %% [markdown]
# ### six paths

# %%
path_4616214=linkcsv(linkId_files[3],2,5,'Monday')
path_4616214
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#       Speed  TravelTime   linkId       Id       Date      Time  Month  Day  \
# 8827  57.17          78  4616214  2814043 2016-02-01  00:00:40      2    1
# 8828  54.06          85  4616214  2814180 2016-02-01  00:05:40      2    1
# 8829  55.30          84  4616214  2814372 2016-02-01  00:10:40      2    1
# 8830  52.82          86  4616214  2814509 2016-02-01  00:15:39      2    1
# 8831  55.30          82  4616214  2814226 2016-02-01  00:20:40      2    1
# ...     ...         ...      ...      ...        ...       ...    ...  ...
# 9094  62.14          81  4616214  2850637 2016-02-01  23:39:40      2    1
# 9095  62.76          79  4616214  2850765 2016-02-01  23:44:40      2    1
# 9096  60.89          82  4616214  2850902 2016-02-01  23:49:40      2    1
# ...

# %%
path_4616215=linkcsv(linkId_files[14],2,5,'Monday')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
path_4616318=linkcsv(linkId_files[15],2,5,'Monday')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
path_4616192=linkcsv(linkId_files[16],2,5,'Monday')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
path_4616259=linkcsv(linkId_files[17],2,5,'Monday')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
path_4616260=linkcsv(linkId_files[18],2,5,'Monday')
path_4616261=linkcsv(linkId_files[51],2,5,'Monday')
path_4616262=linkcsv(linkId_files[70],2,5,'Monday')
path_4616263=linkcsv(linkId_files[91],2,5,'Monday')
path_4616264=linkcsv(linkId_files[101],2,5,'Monday')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning:
#
# Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %% [markdown]
# ### Concatenation

# %%
data = [path_4616214,path_4616215,path_4616318,path_4616192,path_4616259,path_4616260,path_4616261,path_4616262,path_4616263,path_4616264]

result = pd.concat(data)
#result=result.loc(result['Time'].between('06:00:00','08:00:00'))
result
# Out:
#       Speed  TravelTime   linkId       Id       Date      Time  Month  Day  \
# 8827  57.17          78  4616214  2814043 2016-02-01  00:00:40      2    1
# 8828  54.06          85  4616214  2814180 2016-02-01  00:05:40      2    1
# 8829  55.30          84  4616214  2814372 2016-02-01  00:10:40      2    1
# 8830  52.82          86  4616214  2814509 2016-02-01  00:15:39      2    1
# 8831  55.30          82  4616214  2814226 2016-02-01  00:20:40      2    1
# ...     ...         ...      ...      ...        ...       ...    ...  ...
# 9094  47.85         309  4616257  2850541 2016-02-01  23:39:40      2    1
# 9095  44.74         327  4616257  2850669 2016-02-01  23:44:40      2    1
# 9096  44.12         332  4616257  2850797 2016-02-01  23:49:40      2    1
# 9097  47.85         304  4616257  2850934 2016-02-01  23:54:41      2    1
# 9098  49.71         295  4616257  2851065 2016-02-01  23:59:40      2    1
#
#      Weekday  week
# 8827  Monday     5
# 8828  Monday     5
# ...

# %%
#result=result.loc[result['Time'].between('06:00:00','12:00:00')]
#result

result = result.sort_values(by=['Time'], ascending=True)
#esult

# %% [markdown]
# # Data Visualization

# %%
#TRAVEL TIME GRAPH
import plotly.express as px
plot_length = 150
plot_df = result.copy(deep=False).iloc[:plot_length]
#plot_df['weekday'] = plot_df['date'].dt.day_name()

fig = px.line(plot_df,
              x="Time",
              y="Speed", 
              color="linkId", 
              title="Average Speed vs Time for week 1 of February")
fig = px.line(plot_df,
              x="Time",
              y="TravelTime", 
              color="linkId", 
              title="Average Speed vs Time for week 1 of February")
#fig.show()

# %%
def weekly_boxplots(file,mon): 
  """
  This function plots boxplots based on the speeds of each day of the week for a particular month
  
  """                                                                                                                                        
  sns.set(style='whitegrid', rc={"grid.linewidth": 0.2})
  sns.set_context("paper", font_scale=1.5) 
  color = sns.color_palette("Set2", 7)


  plt.figure(figsize=(12, 7))
  plot=sns.boxplot(x='linkId', y='TravelTime', data=file,width=0.8, linewidth = 1.5)
  plot.axes.set_title("Travel time distribution",fontsize=20)
  plot.set_xlabel("Path",fontsize=20)
  plot.set_ylabel("Travel time in Min",fontsize=20)
  return plot

# %%
weekly_boxplots(result,2)

# %% [markdown]
# ## Partitioning the 5 min data

# %%
def montly_extraction(df,n):
  #ETRACTION OF THE MONTHLY DATA
  #HOURLY SUBSAMPLING
  df1=df[::n]
  return df1

# %%
fiveMin=montly_extraction(result,1)
thirtyMin=montly_extraction(result,6)
hourly=montly_extraction(result,12)

# %%
fiveMin
# Out:
#       Speed  TravelTime   linkId       Id       Date      Time  Month  Day  \
# 8827  57.17          78  4616214  2814043 2016-02-01  00:00:40      2    1
# 8827  49.71         311  4616257  2813938 2016-02-01  00:00:40      2    1
# 8827   6.21        1180  4616352  2813966 2016-02-01  00:00:40      2    1
# 8827  59.03         113  4616203  2814048 2016-02-01  00:00:40      2    1
# 8827  16.16         762  4616357  2813953 2016-02-01  00:00:40      2    1
# ...     ...         ...      ...      ...        ...       ...    ...  ...
# 9098  34.18          78  4616341  2851102 2016-02-01  23:59:41      2    1
# 9098  57.17         134  4616352  2851093 2016-02-01  23:59:41      2    1
# 9098  57.17         193  4616351  2851090 2016-02-01  23:59:41      2    1
# 9098  11.18        1073  4616357  2851080 2016-02-01  23:59:41      2    1
# 9098  62.14         177  4616350  2851094 2016-02-01  23:59:41      2    1
#
#      Weekday  week
# 8827  Monday     5
# 8827  Monday     5
# ...

# %% [markdown]
# ## Visualization of the three paths

# %%
def subplots_3paths(df5,df30,df60):
    path1_5=df5.loc[df5['linkId']==4616214]
    path1_30=df30.loc[df30['linkId']==4616214]
    path1_60=df60.loc[df60['linkId']==4616214]

    path2_5=df5.loc[df5['linkId']==4616357]
    path2_30=df30.loc[df30['linkId']==4616357]
    path2_60=df60.loc[df60['linkId']==4616357]

    
    path3_5=df5.loc[df5['linkId']==4616351]
    path3_30=df30.loc[df30['linkId']==4616351]
    path3_60=df60.loc[df60['linkId']==4616351]


    path4_5=df5.loc[df5['linkId']==4616350]
    path4_30=df30.loc[df30['linkId']==4616350]
    path4_60=df60.loc[df60['linkId']==4616350]

    
    fig = plt.figure(figsize=(22,10))
    from matplotlib import colors as mcolors
    from matplotlib import gridspec
    colors = list(dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS).keys())
    gs =gridspec.GridSpec(ncols=3,nrows=4,width_ratios=[1,1,1], height_ratios=[1,1,1,1], hspace=0.5)
    ax0=plt.subplot(gs[0])
    ax0.plot(path1_5['Speed'].values[:int(12*24)],color='b')
    ax0.set_title('Path 4616214: 5 min time interval ')
    ax1=plt.subplot(gs[1])
    ax1.plot(path1_30['Speed'].values[:int(6*24)],color='r')
    ax1.set_title('Path 4616214: 30 min time interval ')
    ax2=plt.subplot(gs[2])
    ax2.plot(path1_60['Speed'].values[:int(24)],color='k')
    ax2.set_title('Path 4616214: 60 min time interval ')


    ax3=plt.subplot(gs[3])
    ax3.plot(path2_5['Speed'].values[:int(12*24)],color='b')
    ax3.set_title('Path 4616357: 5 min time interval ')
    ax4=plt.subplot(gs[4])
    ax4.plot(path2_30['Speed'].values[:int(6*24)],color='r')
    ax4.set_title('Path 4616357: 30 min time interval ')
    ax5=plt.subplot(gs[5])
    ax5.plot(path2_60['Speed'].values[:int(24)],color='k')
    ax5.set_title('Path 4616357: 60 min time interval ')

    ax6=plt.subplot(gs[6])
    ax6.plot(path3_5['Speed'].values[:int(12*24)],color='b')
    ax6.set_title('Path 4616351: 5 min time interval ')
    ax7=plt.subplot(gs[7])
    ax7.plot(path3_30['Speed'].values[:int(6*24)],color='r')
    ax7.set_title('Path 4616351: 30 min time interval ')
    ax8=plt.subplot(gs[8])
    ax8.plot(path3_60['Speed'].values[:int(24)],color='k')
    ax8.set_title('Path 4616351: 60 min time interval ')


    ax9=plt.subplot(gs[9])
    ax9.plot(path4_5['Speed'].values[:int(12*24)],color='b')
    ax9.set_title('Path 4616350: 5 min time interval ')
    ax10=plt.subplot(gs[10])
    ax10.plot(path4_30['Speed'].values[:int(6*24)],color='r')
    ax10.set_title('Path 4616350: 30 min time interval ')
    ax11=plt.subplot(gs[11])
    ax11.plot(path4_60['Speed'].values[:int(24)],color='k')
    ax11.set_title('Path 4616350: 60 min time interval ')

    
    fig.text(0.5, 0.04, 'Time slots', ha='center', va='center')
    fig.text(0.04, 0.5, 'Average speed MPH', ha='center', va='center', rotation='vertical')
    return

# %%
subplots_3paths(fiveMin,thirtyMin,hourly)
